# %% [markdown]
# <a href="https://colab.research.google.com/github/QaziSaim/STUDY-BUDDY/blob/main/Smart_Study_assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installing Necessary Libararies

# %%
# !pip install langchain_openai pypdf

# %%
# %%capture
# !pip install langchain-text-splitters langchain-pinecone langchain-openai

# %%
import os
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.vectorstores
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-1203234334.py in <cell line: 0>()
#       3 from langchain_community.document_loaders import PyPDFLoader
#       4 from langchain_text_splitters import RecursiveCharacterTextSplitter
# ----> 5 from langchain_core.vectorstores import Pinecone
#
# ImportError: cannot import name 'Pinecone' from 'langchain_core.vectorstores' (/usr/local/lib/python3.12/dist-packages/langchain_core/vectorstores/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
